# %% [markdown]
# <a href="https://colab.research.google.com/github/aubricot/computer_vision_with_eol_images/blob/master/object_detection_for_image_tagging/scat_footprint/scat_footprint_train_yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training YOLOv4 to detect scat and footprints from EOL images
# ---
# *Last Updated 3 June 2021*
# -Runs in Python 3-
# Use images with annotations to train YOLOv4 to detect scat and footprints from EOL images.
#
# Datasets were downloaded to Google Drive in [scat_footprint_preprocessing.ipynb](https://github.com/aubricot/computer_vision_with_eol_images/blob/master/object_detection_for_image_tagging/scat_footprint/scat_footprint_preprocessing.ipynb).
#
# **YOLOv4 was trained for 1200 epochs ('iterations').** Scat/footprint object detection models never learned despite adjusting augmentation and model hyperparameters for many training sessions. If successful approaches are found at a later date, steps for adding tags to images will be included. Custom anchor boxes were used to optimize coverage for the dataset and image augmentation was used to increase dataset size from 500 img per class to 1000 img, but loss never decreased below 5 and final mAP was <25%.
#
# Notes:
# * Before you you start: change the runtime to "GPU" with "High RAM"
# * Change filepaths/taxon names where you see 'TO DO'
#
# References:
# * [AlexeyAB's Darknet training instructions - GitHub](https://github.com/AlexeyAB/darknet)
# * [PJReddie's Darknet training instructions - GitHub](https://github.com/pjreddie/darknet)
# * [PJReddie's Darknet training instructions - pjreddie.com](https://pjreddie.com/darknet/yolo/)

# %% [markdown]
# ## Installs & Imports
# ---

# %%
# Mount google drive to import/export files
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Install libraries
# Make sure you are using Python 3.6
# !python --version
# !pip install cython
# !pip install opencv-python

import os
import pathlib
import shutil 
import glob
# Out:
# /content/drive/My Drive/train
# Python 3.7.10
# Collecting tensorflow-gpu==1.15.0rc2
#   Downloading https://files.pythonhosted.org/packages/0e/cb/6a87d29cb8fd853af0104238ab7ceee27f802ea5edbab6eee9e272af2ecd/tensorflow_gpu-1.15.0rc2-cp37-cp37m-manylinux2010_x86_64.whl (411.5MB)
#      |███████████████▊                | 202.7MB 1.3MB/s eta 0:02:37

# %% [markdown]
# ## Model preparation (only run once)

# %%
# Install darknet
# !git clone https://github.com/AlexeyAB/darknet

# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile



# TO DO: Type in the path to your working directory in form field to right
basewd = "/content/drive/MyDrive/train" #@param {type:"string"}
# %cd $basewd

# Download darkflow (the tensorflow implementation of YOLO)
if os.path.exists("darknet"):
    # %cd darknet

elif not os.path.exists("darknet"):
    # !git clone https://github.com/AlexeyAB/darknet
    # Compile darkflow
    # %cd darknet
    # !python setup.py build_ext --inplace
    # Change makefile to have GPU and OPENCV enabled
    # !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
    # !sed -i 's/GPU=0/GPU=1/' Makefile
    # !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
    # !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

wd = 'darknet'
# %cd $wd

# Verify CUDA version (for using GPU)
# !/usr/local/cuda/bin/nvcc --version

# Make darknet
# !make

# %% [markdown]
# ### Train/test dataset preparation (only run once)
# Prepare datasets and make custom anchor box dimensions to help the model learn from image regions based on scat/footprint bounding boxes. Anchor boxes are the regions CNNs use to scan for objects and their dimensions can influence detection results.

# %%
# Copy test images and annotations to darknet
# %cd ../
# !cp test_images/* darknet/build/darknet/x64/data/obj
# !cp test_ann/* darknet/build/darknet/x64/data/obj

print("Number of test images copied to darknet: ")
# !ls test_images | wc -l
print("\nNumber of test annotations copied to darknet: ")
# !ls test_ann | wc -l
print("\nNumber of test dataset files in darknet: ")
# !ls darknet/build/darknet/x64/data/obj | wc -l

# %%
# Copy train images and annotations to darknet

# !cp images/* darknet/build/darknet/x64/data/obj
# !cp annotations/* darknet/build/darknet/x64/data/obj

print("Number of train images copied to darknet: ")
# !ls images | wc -l
print("\nNumber of train annotations copied to darknet: ")
# !ls annotations/  | wc -l
print("\nNumber of train dataset files in darknet: ")
# !ls darknet/build/darknet/x64/data/obj | wc -l

# %%
# Delete tf.record files from copied train and test images (leftover from tensorflow object detection)
path = "build/darknet/x64/data/obj"

files = os.listdir(path)
flist = [file for file in files if file.endswith(".record")]
for file in flist:
  fpath = os.path.join(path, file)
  os.remove(fpath)

# %%
# Convert xml annotations to YOLOv4 format
# %cd darknet/build/darknet/x64/data/obj

# !python xml_to_yolo.py

# !rm -r ./*.xml

# %cd ../
# !mv labels/xml_to_yolo.py ..

# %%
# Make train.txt and test.txt files that list images needed by YOLOv3 for training
# %cd $wd
# %cd ../

# Train dataset
path = "images"
with open('train.txt', 'w', encoding='utf-8') as f:
  for dir, dirs, files in os.walk(path):
    files = [fn for fn in files]
    for fn in files:
      fn = "build/darknet/x64/data/obj/" + fn
      f.writelines(fn + '\n')

# Test dataset
path = "test_images"
with open('test.txt', 'w', encoding='utf-8') as f:
  for dir, dirs, files in os.walk(path):
    files = [fn for fn in files if not fn.endswith('.record')]
    for fn in files:
      fn = "build/darknet/x64/data/obj/" + fn
      f.writelines(fn + '\n')

# %%
# Generate custom anchor box dimensions based on annotation sizes in training dataset
# Copy these values to cfg files for training to improve accuracy
# %cd $wd

# !python build/darknet/x64/gen_anchors.py -filelist build/darknet/x64/data/train.txt -output_dir ./ -num_clusters 5

# %% [markdown]
# ## Train the model
# ---

# %%
# Build darknet during each training session, even if model and datasets were made in previous sessions

# TO DO: Type in the path to your working directory in form field to right
wd = "/content/drive/MyDrive/train/darknet" #@param {type:"string"}
# %cd $wd

# Verify CUDA version (for using GPU)
# !/usr/local/cuda/bin/nvcc --version

# Make darknet
# !make

# Copy original model config file to yolo-obj.cfg to use as a working file 
# Double click the cfg file in Colab's file explorer to open Colab's text editor
# You can adjust hyperparameters and anchor box dimensions
# !cp cfg/yolov4-custom.cfg cfg/yolo-obj.cfg

# %%
# Actual training
# add the flag -clear if retraining from scratch, otherwise re-running will build on previous training steps

# !./darknet detector train build/darknet/x64/data/obj.data cfg/yolo-obj.cfg build/darknet/x64/yolov4.conv.137 -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# Loaded: 0.928430 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.669652), count: 9, class_loss = 10.089470, iou_loss = 44.362110, total_loss = 54.451580
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.610823), count: 11, class_loss = 6.928715, iou_loss = 12.349678, total_loss = 19.278393
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.483342), count: 3, class_loss = 3.284615, iou_loss = 0.186281, total_loss = 3.470897
#  total_bbox = 1175437, rewritten_bbox = 0.019993 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.548722), count: 10, class_loss = 10.704034, iou_loss = 27.818192, total_loss = 38.522224
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0

# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.675364), count: 2, class_loss = 3.110682, iou_loss = 0.080849, total_loss = 3.191531
#  total_bbox = 1186837, rewritten_bbox = 0.020138 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.670705), count: 12, class_loss = 10.279037, iou_loss = 48.310982, total_loss = 58.590019
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.709376), count: 25, class_loss = 13.911197, iou_loss = 28.336994, total_loss = 42.248192
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.649506), count: 6, class_loss = 4.525745, iou_loss = 2.386065, total_loss = 6.911810
#  total_bbox = 1186880, rewritten_bbox = 0.020137 %
#
#  (next mAP calculation at 1200 iterations)
#  Last accuracy mAP@0.5 = 25.08 %, best = 25.08 %
#  1142: 5.012127, 5.088248 avg loss, 0.001000 rate, 6.582588 seconds, 73088 images, 8.912620 hours left
# Loaded: 0.000028 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.007742, iou_loss = 0.000000, total_loss = 0.007742
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.644620), count: 7, class_loss = 6.478673, iou_loss = 4.167552, total_loss = 10.646226
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.616904), count: 5, class_loss = 3.788161, iou_loss = 0.948074, total_loss = 4.736235
#  total_bbox = 1186892, rewritten_bbox = 0.020137 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.713675), count: 25, class_loss = 18.430412, iou_loss = 208.261963, total_loss = 226.692383
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.541098), count: 20, class_loss = 16.301298, iou_loss = 22.772535, total_loss = 39.073833
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.000000), count: 1, class_loss = 0.395609, iou_loss = 0.000000, total_loss = 0.395609
#  total_bbox = 1186937, rewritten_bbox = 0.020136 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.517378), count: 14, class_loss = 19.834951, iou_loss = 54.708153, total_loss = 74.543106
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.351574), count: 7, class_loss = 8.035997, iou_loss = 1.678328, total_loss = 9.714325
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.457584), count: 3, class_loss = 3.064502, iou_loss = 0.294029, total_loss = 3.358531
#  total_bbox = 1186961, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.668121), count: 2, class_loss = 1.973546, iou_loss = 7.803023, total_loss = 9.776568
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.446042), count: 2, class_loss = 1.913134, iou_loss = 0.647223, total_loss = 2.560356
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.567285), count: 3, class_loss = 3.623631, iou_loss = 0.124901, total_loss = 3.748533
#  total_bbox = 1186968, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.130442, iou_loss = 0.000000, total_loss = 0.130442
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.287752, iou_loss = 0.000000, total_loss = 0.287752
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.821857), count: 2, class_loss = 3.679467, iou_loss = 0.128192, total_loss = 3.807660
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#  total_bbox = 1186970, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.003141, iou_loss = 0.000000, total_loss = 0.003141
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.625469), count: 2, class_loss = 1.950756, iou_loss = 1.205343, total_loss = 3.156098
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.607902), count: 2, class_loss = 1.360218, iou_loss = 0.172127, total_loss = 1.532345
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#  total_bbox = 1186974, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.003267, iou_loss = 0.000000, total_loss = 0.003267
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.585409), count: 3, class_loss = 2.940710, iou_loss = 2.453571, total_loss = 5.394281
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.714523), count: 1, class_loss = 1.247139, iou_loss = 1.032885, total_loss = 2.280024
#  total_bbox = 1186978, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.674536), count: 5, class_loss = 3.668945, iou_loss = 17.523705, total_loss = 21.192650
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.743822), count: 12, class_loss = 5.699551, iou_loss = 18.554098, total_loss = 24.253649
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.758243), count: 2, class_loss = 0.304004, iou_loss = 1.085125, total_loss = 1.389129
#  total_bbox = 1186997, rewritten_bbox = 0.020135 %
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
#
# You use flag -show_imgs, so will be saved aug_...jpg images. Click on window and press ESC button
